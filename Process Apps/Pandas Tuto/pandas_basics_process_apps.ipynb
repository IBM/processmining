# %% [markdown]
# # Using PANDAS for process mining data transformation and process apps
# Python is powerful to manipulate data for data science, and therefore for process mining.
# Pandas is a very efficient python library for manipulating tables of data. That's a premium choice for creating a process mining event log.
#
# The IBM Process Mining process apps require to create a python function that returns the event log as a Pandas dataframe.
#
# If Pandas is powerful, I often wasted time trying to remind how some functions work.
# In this article we review pandas functions often used to create an eventlog from one or several data source.

# %% [markdown]
# ## Using REST APIs to get data
# REST APIs are often used to fetch data from the IT applications involved in the processes. You can read examples for such REST calls using request in Process Apps/BAW BPM/BAW_BPMN_ProcessApp.py or in Process Apps/IT_Ticketing_ServiceNow/ServiceNowConnector.py
#
# Most REST APIs return a JSON object that can be used to create a Pandas data frame

# %%
import pandas as pd

a_json_returned_by_REST_CALL = [
    {'processid':'p1', 'activity':'analyze request', 'date':'2023-01-01'},
    {'processid':'p1', 'activity':'approve request', 'date':'2023-01-02'},
    {'processid':'p2', 'activity':'approve request', 'date':'2023-01-02'},
    {'processid':'p2', 'activity':'reject request', 'date':'2023-01-04'},
    ]
df = pd.DataFrame(a_json_returned_by_REST_CALL)
df
# Out:
#   processid         activity        date
# 0        p1  analyze request  2023-01-01
# 1        p1  approve request  2023-01-02
# 2        p2  approve request  2023-01-02
# 3        p2   reject request  2023-01-04

# %% [markdown]
# To avoid having to connect to an external service, we will load CSV files to create the dataframes. These CSV files are generated from using ServiceNow rest APIs. Below are some basic dataframe functions:

# %%
incidents_df = pd.read_csv('../IT_Ticketing_ServiceNow/incidents_REST.csv')
print("incidents_df columns: %s" % incidents_df.columns) 
print("incidents_df length: %s" % len(incidents_df))
print("incident number: %s" % incidents_df['number'])
print("incident number and status: %s" % incidents_df[['number','incident_state']])
# Out:
# incidents_df columns: Index(['short_description', 'close_code', 'made_sla', 'assignment_group',
#        'business_stc', 'sys_updated_on', 'hold_reason', 'closed_by',
#        'parent_incident', 'number', 'sys_id', 'contact_type', 'resolved_by',
#        'reopened_by', 'sys_updated_by', 'incident_state', 'urgency',
#        'opened_by', 'sys_created_on', 'reassignment_count', 'sys_created_by',
#        'severity', 'calendar_stc', 'closed_at', 'impact', 'sys_mod_count',
#        'active', 'reopen_count', 'priority', 'opened_at', 'resolved_at',
#        'reopened_time', 'category', 'subcategory'],
#       dtype='object')
# incidents_df length: 67
# incident number: 0     INC0000060
# 1     INC0009002
# 2     INC0000009
# 3     INC0000010
# 4     INC0000011
#          ...
# 62    INC0009005
# 63    INC0000049
# 64    INC0000050
# 65    INC0007001
# 66    INC0007002
# Name: number, Length: 67, dtype: object
# incident number and status:         number  incident_state
# 0   INC0000060               7
# 1   INC0009002               7
# 2   INC0000009               7
# 3   INC0000010               7
# 4   INC0000011               7
# ..         ...             ...
# 62  INC0009005               1
# 63  INC0000049               2
# 64  INC0000050               2
# 65  INC0007001               1
# 66  INC0007002               1
#
# [67 rows x 2 columns]

# %% [markdown]
# ## Managing columns
# You might want to remove columns, to rename columns, or to change the order of columns:

# %%
df = incidents_df.copy()
# Remove columns. Drop works on a copy of the dataframe:
df.drop(columns=['reassignment_count','sys_mod_count'])
# Remove columns. Drop changes the data frame:
df.drop(columns=['sys_mod_count','sys_mod_count'], inplace=True)
# Rename columns
df.rename(columns={'number':'incident_number', 'sys_updated_by':'user_id'})
# Or rename in place
df.rename(columns={'number':'incident_number', 'sys_updated_by':'user_id'}, inplace=True)
# Keep some columns and/or change their order
df[['incident_number','sys_updated_on','user_id']]
# Out:
#    incident_number       sys_updated_on   user_id
# 0       INC0000060  2016-12-14 02:46:44  employee
# 1       INC0009002  2023-01-11 19:03:10    system
# 2       INC0000009  2023-01-10 20:16:04     admin
# 3       INC0000010  2023-01-10 20:16:35     admin
# 4       INC0000011  2023-01-10 19:56:31     admin
# ..             ...                  ...       ...
# 62      INC0009005  2018-12-13 07:18:55     admin
# 63      INC0000049  2023-01-10 19:52:34     admin
# 64      INC0000050  2023-01-10 19:49:40     admin
# 65      INC0007001  2023-01-11 18:52:05    system
# 66      INC0007002  2018-12-13 07:28:49     admin
#
# [67 rows x 3 columns]

# %% [markdown]
# ## Managing rows
# Rows in Pandas are called indexes.

# %%
# Selecting one row
df = incidents_df.copy()
df.iloc[1]
# Selecting several rows
df.iloc[[2,5]]
df.iloc[:3]
# Selecting both rows and columns
df.iloc[[0, 2], [1, 4]] # rows 0 and 2, columns 1 and 4
# Out:
#                   close_code  business_stc
# 0       Solved (Permanently)       28800.0
# 2  Closed/Resolved by Caller     1749949.0

# %% [markdown]
# ## Filtering

# %%
df = incidents_df.copy()
# Keep rows for which 'incident_state' == 2
df[df['incident_state']==2].head() # head() shows the firts five rows
# Out:
#                                     short_description close_code  made_sla  \
# 28  I can't launch my VPN client since the last so...        NaN     False
# 29                 Rain is leaking on main DNS Server        NaN     False
# 31            Sales forecast spreadsheet is READ ONLY        NaN     False
# 32      Can't launch 64-bit Windows 7 virtual machine        NaN     False
# 33                I need a replacement iPhone, please        NaN     False
#
#                     assignment_group  business_stc       sys_updated_on  \
# 28  8a4dde73c6112278017a6a4baf547aa7      432000.0  2023-01-10 19:50:33
# 29  8a5055c9c61122780043563ef53438e3      959937.0  2023-01-10 19:51:23
# 31                               NaN        9173.0  2023-01-10 19:37:49
# 32                               NaN      268184.0  2023-01-10 19:46:13
# 33                               NaN           NaN  2023-01-10 19:45:32
#
#     hold_reason                         closed_by parent_incident      number  \
# 28          NaN                               NaN             NaN  INC0000015
# 29          NaN  6816f79cc0a8016401c5a33be04be441             NaN  INC0000016
# 31          NaN                               NaN             NaN  INC0000018
# 32          NaN                               NaN             NaN  INC0000019
# 33          NaN                               NaN             NaN  INC0000020
#
#     ... impact sys_mod_count active  reopen_count priority  \
# 28  ...      1            11   True           NaN        1
# 29  ...      1             7   True           NaN        1
# 31  ...      1             8   True           NaN        1
# 32  ...      2            10   True           NaN        2
# 33  ...      3             6   True           NaN        5
#
#               opened_at  resolved_at reopened_time  category  subcategory
# 28  2022-09-26 23:38:46          NaN           NaN  software          NaN
# 29  2022-09-21 23:40:23          NaN           NaN  hardware          NaN
# 31  2022-09-27 23:42:46          NaN           NaN       NaN          NaN
# 32  2022-09-29 23:44:39          NaN           NaN  software          NaN
# 33  2022-10-09 23:51:35          NaN           NaN   inquiry          NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Managing NaN
# Non existant data are represented as NaN in Pandas.
# You might want to replace NaN by something. For example ''

# %%
df=incidents_df.copy()
# isna() returns a 'mask' 
df.isna()
# Out:
#     short_description  close_code  made_sla  assignment_group  business_stc  \
# 0               False       False     False             False         False
# 1               False       False     False              True         False
# 2               False       False     False             False         False
# 3               False       False     False             False         False
# 4               False       False     False             False         False
# ..                ...         ...       ...               ...           ...
# 62              False        True     False              True          True
# 63              False        True     False             False          True
# 64              False        True     False             False          True
# 65              False        True     False             False          True
# 66              False        True     False              True          True
#
#     sys_updated_on  hold_reason  closed_by  parent_incident  number  ...  \
# 0            False         True      False             True   False  ...
# 1            False         True      False             True   False  ...
# 2            False         True      False             True   False  ...
# 3            False         True      False             True   False  ...
# 4            False         True      False             True   False  ...
# ..             ...          ...        ...              ...     ...  ...
# 62           False         True       True             True   False  ...
# 63           False         True       True             True   False  ...
# 64           False         True       True             True   False  ...
# 65           False         True       True             True   False  ...
# 66           False         True       True            False   False  ...
#
#     impact  sys_mod_count  active  reopen_count  priority  opened_at  \
# 0    False          False   False         False     False      False
# 1    False          False   False         False     False      False
# 2    False          False   False          True     False      False
# 3    False          False   False          True     False      False
# 4    False          False   False          True     False      False
# ..     ...            ...     ...           ...       ...        ...
# 62   False          False   False         False     False      False
# 63   False          False   False          True     False      False
# 64   False          False   False          True     False      False
# 65   False          False   False         False     False      False
# 66   False          False   False         False     False      False
#
#     resolved_at  reopened_time  category  subcategory
# 0         False           True     False        False
# 1         False           True     False         True
# 2         False           True     False         True
# 3         False           True     False         True
# 4         False           True     False         True
# ..          ...            ...       ...          ...
# 62         True           True     False        False
# 63         True           True     False         True
# 64         True           True     False         True
# 65         True           True     False         True
# 66         True           True     False         True
#
# [67 rows x 34 columns]

# %%
# isna() can also be used on a column.
df[~df['close_code'].isna()] # Keep the rows (the records) where 'close_code' is not empty (not NaN)
# Out:
#                                     short_description  \
# 0                          Unable to connect to email
# 1   My computer is not detecting the headphone device
# 2                                   Reset my password
# 3                         Need Oracle 10GR2 installed
# 4                          Need new Blackberry set up
# 5                        Customer didn't receive eFax
# 6        EMAIL is slow when an attachment is involved
# 7                           Missing my home directory
# 8                                   New employee hire
# 9                       Issue with a web page on wiki
# 10        Seem to have an issue with my hard drive...
# 11  My disk is still having issues. Can't delete a...
# 12            Lost connection to the wireless network
# 13                            EMAIL Server Down Again
# 14            File Server is 80% full - Needs upgrade
# 15    Does not look like a backup occurred last night
# 16                                  Reset my password
# 17                              Issue with networking
# 18            my PDF docs are all locked from editing
# 19          Hangs when trying to print VISIO document
# 20               Printer in my office is out of toner
# 21                                   Can't read email
# 22                              Forgot email password
# 23              The USB port on my PC stopped working
# 24            Cannot sign into the company portal app
# 25                      Defect tracking tool is down.
# 26                  CPU load high for over 10 minutes
#
#                        close_code  made_sla                  assignment_group  \
# 0            Solved (Permanently)      True  287ebd7da9fe198100f92cc8d1d2154e
# 1            Solved (Permanently)      True                               NaN
# 2       Closed/Resolved by Caller     False  d625dccec0a8016700a222a0f7900d06
# 3       Closed/Resolved by Caller     False  287ee6fea9fe198100ada7950d0b1b73
# 4       Closed/Resolved by Caller     False  8a5055c9c61122780043563ef53438e3
# 5       Closed/Resolved by Caller     False  287ee6fea9fe198100ada7950d0b1b73
# 6            Solved (Work Around)     False  8a4dde73c6112278017a6a4baf547aa7
# 7            Solved (Work Around)     False                               NaN
# 8       Closed/Resolved by Caller     False                               NaN
# 9       Closed/Resolved by Caller     False  d625dccec0a8016700a222a0f7900d06
# 10      Closed/Resolved by Caller     False  8a5055c9c61122780043563ef53438e3
# 11      Closed/Resolved by Caller     False  d625dccec0a8016700a222a0f7900d06
# 12      Closed/Resolved by Caller     False  287ebd7da9fe198100f92cc8d1d2154e
# 13      Closed/Resolved by Caller     False  8a5055c9c61122780043563ef53438e3
# 14      Closed/Resolved by Caller     False  8a5055c9c61122780043563ef53438e3
# 15  Solved Remotely (Permanently)     False  8a4dde73c6112278017a6a4baf547aa7
# 16      Closed/Resolved by Caller     False  d625dccec0a8016700a222a0f7900d06
# 17      Closed/Resolved by Caller     False  287ebd7da9fe198100f92cc8d1d2154e
# 18      Closed/Resolved by Caller     False  d625dccec0a8016700a222a0f7900d06
# 19      Closed/Resolved by Caller     False  8a4dde73c6112278017a6a4baf547aa7
# 20      Closed/Resolved by Caller     False  8a5055c9c61122780043563ef53438e3
# 21      Closed/Resolved by Caller     False  d625dccec0a8016700a222a0f7900d06
# 22           Solved (Work Around)     False  d625dccec0a8016700a222a0f7900d06
# 23           Solved (Work Around)      True                               NaN
# 24           Solved (Work Around)      True                               NaN
# 25           Solved (Work Around)      True                               NaN
# 26      Closed/Resolved by Caller     False  8a5055c9c61122780043563ef53438e3
#
#     business_stc       sys_updated_on  hold_reason  \
# 0        28800.0  2016-12-14 02:46:44          NaN
# 1            0.0  2023-01-11 19:03:10          NaN
# 2      1749949.0  2023-01-10 20:16:04          NaN
# 3      1864990.0  2023-01-10 20:16:35          NaN
# 4      1720500.0  2023-01-10 19:56:31          NaN
# 5      2209752.0  2023-01-10 19:56:12          NaN
# 6      1661930.0  2023-01-10 19:54:48          NaN
# 7      2301243.0  2023-01-11 19:03:10          NaN
# 8      1746251.0  2023-01-10 19:56:12          NaN
# 9      1631000.0  2023-01-10 20:15:44          NaN
# 10     2235673.0  2023-01-10 20:15:35          NaN
# 11     2033892.0  2023-01-10 20:15:31          NaN
# 12     1716900.0  2023-01-10 20:15:37          NaN
# 13     2061396.0  2023-01-10 20:15:54          NaN
# 14     2183601.0  2023-01-10 20:15:24          NaN
# 15     2061992.0  2023-01-10 19:53:47          NaN
# 16     1713373.0  2023-01-10 20:16:15          NaN
# 17     1743744.0  2023-01-10 19:57:58          NaN
# 18     1743569.0  2023-01-10 19:57:55          NaN
# 19     1892887.0  2023-01-10 20:15:59          NaN
# 20     1720053.0  2023-01-10 20:16:02          NaN
# 21     1892781.0  2023-01-10 20:16:07          NaN
# 22     1751222.0  2023-01-10 20:16:24          NaN
# 23       86400.0  2023-05-07 18:15:46          NaN
# 24           0.0  2018-12-13 07:39:53          NaN
# 25           0.0  2023-01-11 19:03:10          NaN
# 26     1869258.0  2023-01-11 19:03:10          NaN
#
#                            closed_by parent_incident      number  ... impact  \
# 0   681ccaf9c0a8016400b98a06818d57c7             NaN  INC0000060  ...      2
# 1   6816f79cc0a8016401c5a33be04be441             NaN  INC0009002  ...      2
# 2   9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000009  ...      1
# 3   9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000010  ...      2
# 4   9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000011  ...      2
# 5   9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000012  ...      3
# 6   9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000013  ...      1
# 7   6816f79cc0a8016401c5a33be04be441             NaN  INC0000014  ...      1
# 8   5137153cc611227c000bbd1bd8cd2007             NaN  INC0000021  ...      3
# 9   5137153cc611227c000bbd1bd8cd2007             NaN  INC0000024  ...      3
# 10  9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000026  ...      3
# 11  9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000028  ...      3
# 12  9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000030  ...      3
# 13  9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000032  ...      3
# 14  9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000033  ...      1
# 15  9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000034  ...      1
# 16  5137153cc611227c000bbd1bd8cd2007             NaN  INC0000035  ...      3
# 17  5137153cc611227c000bbd1bd8cd2007             NaN  INC0000036  ...      3
# 18  6816f79cc0a8016401c5a33be04be441             NaN  INC0000038  ...      2
# 19  9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000006  ...      1
# 20  9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000008  ...      1
# 21  9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000001  ...      1
# 22  9ee1b13dc6112271007f9d0efdb69cd0             NaN  INC0000004  ...      1
# 23  62d78687c0a8010e00b3d84178adc913             NaN  INC0000601  ...      3
# 24  6816f79cc0a8016401c5a33be04be441             NaN  INC0009003  ...      2
# 25  6816f79cc0a8016401c5a33be04be441             NaN  INC0009004  ...      3
# 26  6816f79cc0a8016401c5a33be04be441             NaN  INC0000005  ...      1
#
#    sys_mod_count active  reopen_count priority            opened_at  \
# 0             15  False           0.0        3  2016-12-12 15:19:57
# 1              9  False           0.0        3  2018-09-16 12:49:23
# 2              8  False           NaN        1  2022-10-17 22:50:23
# 3              8  False           NaN        4  2022-10-11 22:53:02
# 4              7  False           NaN        3  2022-10-18 23:01:12
# 5              6  False           NaN        5  2022-09-25 23:07:00
# 6              5  False           NaN        1  2022-10-22 23:15:58
# 7             33  False           NaN        1  2022-09-15 23:37:35
# 8              8  False           NaN        5  2022-10-17 23:52:01
# 9              6  False           NaN        5  2022-10-23 23:52:52
# 10             6  False           NaN        5  2022-09-24 23:54:59
# 11             6  False           NaN        5  2022-10-03 23:58:00
# 12             6  False           NaN        5  2022-10-19 00:01:12
# 13             6  False           NaN        5  2022-10-03 00:19:36
# 14             6  False           NaN        1  2022-09-26 22:22:52
# 15             7  False           NaN        1  2022-09-23 20:25:29
# 16             8  False           NaN        5  2022-10-21 00:32:47
# 17             6  False           NaN        5  2022-10-18 00:33:49
# 18             5  False           NaN        4  2022-10-18 00:36:44
# 19            14  False           NaN        1  2022-10-10 23:08:05
# 20            19  False           NaN        1  2022-10-18 23:08:39
# 21            21  False           NaN        1  2022-10-10 23:09:51
# 22             9  False           NaN        1  2022-10-17 22:49:22
# 23             2  False           0.0        5  2023-01-06 09:42:59
# 24             4  False           0.0        3  2018-08-30 09:17:32
# 25             9  False           0.0        3  2018-09-01 13:13:30
# 26            15  False           NaN        1  2022-10-06 23:06:52
#
#             resolved_at reopened_time  category  subcategory
# 0   2016-12-13 21:43:14           NaN   inquiry        email
# 1   2018-09-16 12:51:17           NaN  Hardware          NaN
# 2   2023-01-10 19:56:12           NaN   inquiry          NaN
# 3   2023-01-10 19:56:12           NaN  database          NaN
# 4   2023-01-10 19:56:12           NaN   inquiry          NaN
# 5   2023-01-10 19:56:12           NaN  software          NaN
# 6   2023-01-10 19:54:48           NaN   inquiry          NaN
# 7   2023-01-03 23:14:03           NaN   inquiry          NaN
# 8   2023-01-10 19:56:12           NaN   inquiry          NaN
# 9   2023-01-10 19:56:12           NaN   inquiry          NaN
# 10  2023-01-10 19:56:12           NaN  hardware          NaN
# 11  2023-01-10 19:56:12           NaN   inquiry          NaN
# 12  2023-01-10 19:56:12           NaN  hardware          NaN
# 13  2023-01-10 19:56:12           NaN   inquiry          NaN
# 14  2023-01-10 19:56:13           NaN   inquiry          NaN
# 15  2023-01-01 16:12:01           NaN  software          NaN
# 16  2023-01-10 19:56:13           NaN   inquiry          NaN
# 17  2023-01-10 19:56:13           NaN   inquiry          NaN
# 18  2023-01-10 19:56:13           NaN  software          NaN
# 19  2023-01-10 19:56:12           NaN  software          NaN
# 20  2023-01-10 19:56:12           NaN   inquiry          NaN
# 21  2023-01-10 19:56:12           NaN   network          NaN
# 22  2023-01-10 20:16:24           NaN   inquiry          NaN
# 23  2023-01-09 11:09:56           NaN  hardware          NaN
# 24  2018-08-30 09:49:17           NaN   inquiry          NaN
# 25  2018-09-01 13:18:53           NaN  software          NaN
# 26  2023-01-03 23:14:18           NaN  hardware          NaN
#
# [27 rows x 34 columns]

# %%
# We can also replace NaN with a value, such that we can use this value
df.fillna('')
# Out:
#                                     short_description  \
# 0                          Unable to connect to email
# 1   My computer is not detecting the headphone device
# 2                                   Reset my password
# 3                         Need Oracle 10GR2 installed
# 4                          Need new Blackberry set up
# ..                                                ...
# 62                              Email server is down.
# 63                        Network storage unavailable
# 64         Can't access Exchange server - is it down?
# 65       Employee payroll application server is down.
# 66                   Need access to the common drive.
#
#                    close_code  made_sla                  assignment_group  \
# 0        Solved (Permanently)      True  287ebd7da9fe198100f92cc8d1d2154e
# 1        Solved (Permanently)      True
# 2   Closed/Resolved by Caller     False  d625dccec0a8016700a222a0f7900d06
# 3   Closed/Resolved by Caller     False  287ee6fea9fe198100ada7950d0b1b73
# 4   Closed/Resolved by Caller     False  8a5055c9c61122780043563ef53438e3
# ..                        ...       ...                               ...
# 62                                 True
# 63                                 True  8a5055c9c61122780043563ef53438e3
# 64                                 True  8a5055c9c61122780043563ef53438e3
# 65                                 True  36c741fa731313005754660c4cf6a70d
# 66                                 True
#
#    business_stc       sys_updated_on hold_reason  \
# 0       28800.0  2016-12-14 02:46:44
# 1           0.0  2023-01-11 19:03:10
# 2     1749949.0  2023-01-10 20:16:04
# 3     1864990.0  2023-01-10 20:16:35
# 4     1720500.0  2023-01-10 19:56:31
# ..          ...                  ...         ...
# 62               2018-12-13 07:18:55
# 63               2023-01-10 19:52:34
# 64               2023-01-10 19:49:40
# 65               2023-01-11 18:52:05
# 66               2018-12-13 07:28:49
#
#                            closed_by                   parent_incident  \
# 0   681ccaf9c0a8016400b98a06818d57c7
# 1   6816f79cc0a8016401c5a33be04be441
# 2   9ee1b13dc6112271007f9d0efdb69cd0
# 3   9ee1b13dc6112271007f9d0efdb69cd0
# 4   9ee1b13dc6112271007f9d0efdb69cd0
# ..                               ...                               ...
# 62
# 63
# 64
# 65
# 66                                    f12ca184735123002728660c4cf6a7ef
#
#         number  ... impact sys_mod_count active reopen_count priority  \
# 0   INC0000060  ...      2            15  False          0.0        3
# 1   INC0009002  ...      2             9  False          0.0        3
# 2   INC0000009  ...      1             8  False                     1
# 3   INC0000010  ...      2             8  False                     4
# 4   INC0000011  ...      2             7  False                     3
# ..         ...  ...    ...           ...    ...          ...      ...
# 62  INC0009005  ...      1             3   True          0.0        1
# 63  INC0000049  ...      2            37   True                     2
# 64  INC0000050  ...      1             5   True                     1
# 65  INC0007001  ...      1             7   True          0.0        1
# 66  INC0007002  ...      3             4   True          0.0        4
#
#               opened_at          resolved_at reopened_time  category  \
# 0   2016-12-12 15:19:57  2016-12-13 21:43:14                 inquiry
# 1   2018-09-16 12:49:23  2018-09-16 12:51:17                Hardware
# 2   2022-10-17 22:50:23  2023-01-10 19:56:12                 inquiry
# 3   2022-10-11 22:53:02  2023-01-10 19:56:12                database
# 4   2022-10-18 23:01:12  2023-01-10 19:56:12                 inquiry
# ..                  ...                  ...           ...       ...
# 62  2018-09-01 04:35:21                                     software
# 63  2022-12-20 21:56:37                                      network
# 64  2022-12-20 21:58:24                                     hardware
# 65  2018-10-17 05:47:10                                     hardware
# 66  2018-10-17 05:47:51                                      inquiry
#
#    subcategory
# 0        email
# 1
# 2
# 3
# 4
# ..         ...
# 62       email
# 63
# 64
# 65
# 66
#
# [67 rows x 34 columns]

# %% [markdown]
# ## Managing groups of cells
# We would like to create some data, with using other columns and conditions

# %% [markdown]
# Creating a new column, with a value that depends on a condition

# %%
df = incidents_df.copy()
df = df.fillna('')
df.loc[df['close_code'] == '','close_comment'] = 'not closed ' + df['closed_by']
df.loc[df['close_code'] != '','close_comment'] = 'Closed by ' +  + df['closed_by']

df
# Out:
#                                     short_description  \
# 0                          Unable to connect to email
# 1   My computer is not detecting the headphone device
# 2                                   Reset my password
# 3                         Need Oracle 10GR2 installed
# 4                          Need new Blackberry set up
# ..                                                ...
# 62                              Email server is down.
# 63                        Network storage unavailable
# 64         Can't access Exchange server - is it down?
# 65       Employee payroll application server is down.
# 66                   Need access to the common drive.
#
#                    close_code  made_sla                  assignment_group  \
# 0        Solved (Permanently)      True  287ebd7da9fe198100f92cc8d1d2154e
# 1        Solved (Permanently)      True
# 2   Closed/Resolved by Caller     False  d625dccec0a8016700a222a0f7900d06
# 3   Closed/Resolved by Caller     False  287ee6fea9fe198100ada7950d0b1b73
# 4   Closed/Resolved by Caller     False  8a5055c9c61122780043563ef53438e3
# ..                        ...       ...                               ...
# 62                                 True
# 63                                 True  8a5055c9c61122780043563ef53438e3
# 64                                 True  8a5055c9c61122780043563ef53438e3
# 65                                 True  36c741fa731313005754660c4cf6a70d
# 66                                 True
#
#    business_stc       sys_updated_on hold_reason  \
# 0       28800.0  2016-12-14 02:46:44
# 1           0.0  2023-01-11 19:03:10
# 2     1749949.0  2023-01-10 20:16:04
# 3     1864990.0  2023-01-10 20:16:35
# 4     1720500.0  2023-01-10 19:56:31
# ..          ...                  ...         ...
# 62               2018-12-13 07:18:55
# 63               2023-01-10 19:52:34
# 64               2023-01-10 19:49:40
# 65               2023-01-11 18:52:05
# 66               2018-12-13 07:28:49
#
#                            closed_by                   parent_incident  \
# 0   681ccaf9c0a8016400b98a06818d57c7
# 1   6816f79cc0a8016401c5a33be04be441
# 2   9ee1b13dc6112271007f9d0efdb69cd0
# 3   9ee1b13dc6112271007f9d0efdb69cd0
# 4   9ee1b13dc6112271007f9d0efdb69cd0
# ..                               ...                               ...
# 62
# 63
# 64
# 65
# 66                                    f12ca184735123002728660c4cf6a7ef
#
#         number  ... sys_mod_count active reopen_count priority  \
# 0   INC0000060  ...            15  False          0.0        3
# 1   INC0009002  ...             9  False          0.0        3
# 2   INC0000009  ...             8  False                     1
# 3   INC0000010  ...             8  False                     4
# 4   INC0000011  ...             7  False                     3
# ..         ...  ...           ...    ...          ...      ...
# 62  INC0009005  ...             3   True          0.0        1
# 63  INC0000049  ...            37   True                     2
# 64  INC0000050  ...             5   True                     1
# 65  INC0007001  ...             7   True          0.0        1
# 66  INC0007002  ...             4   True          0.0        4
#
#               opened_at          resolved_at  reopened_time  category  \
# 0   2016-12-12 15:19:57  2016-12-13 21:43:14                  inquiry
# 1   2018-09-16 12:49:23  2018-09-16 12:51:17                 Hardware
# 2   2022-10-17 22:50:23  2023-01-10 19:56:12                  inquiry
# 3   2022-10-11 22:53:02  2023-01-10 19:56:12                 database
# 4   2022-10-18 23:01:12  2023-01-10 19:56:12                  inquiry
# ..                  ...                  ...            ...       ...
# 62  2018-09-01 04:35:21                                      software
# 63  2022-12-20 21:56:37                                       network
# 64  2022-12-20 21:58:24                                      hardware
# 65  2018-10-17 05:47:10                                      hardware
# 66  2018-10-17 05:47:51                                       inquiry
#
#    subcategory                               close_comment
# 0        email  Closed by 681ccaf9c0a8016400b98a06818d57c7
# 1               Closed by 6816f79cc0a8016401c5a33be04be441
# 2               Closed by 9ee1b13dc6112271007f9d0efdb69cd0
# 3               Closed by 9ee1b13dc6112271007f9d0efdb69cd0
# 4               Closed by 9ee1b13dc6112271007f9d0efdb69cd0
# ..         ...                                         ...
# 62       email                                 not closed
# 63                                             not closed
# 64                                             not closed
# 65                                             not closed
# 66                                             not closed
#
# [67 rows x 35 columns]
